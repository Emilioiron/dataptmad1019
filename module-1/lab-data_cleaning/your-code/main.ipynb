# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
# !pip install sqlalchemy

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
# !pip install pymysql

import pymysql
from sqlalchemy import create_engine

# See web:https://docs.sqlalchemy.org/en/13/core/engines.html#
# for parameters of connection server

engine = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz/stats')

# %% [markdown]
# #### 4. Import the users table

# %%
df_users = pd.read_sql_query("select * from users", engine)

df_users.head(10)
# Out:
#    Id  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0  -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1   2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2   3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3   4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4   5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
# 5   6         457 2010-07-19 19:04:07        Harlan 2014-08-07 19:49:44
# 6   7         429 2010-07-19 19:04:37         Vince 2014-09-10 21:14:12
# 7   8        6764 2010-07-19 19:04:52   csgillespie 2014-09-09 21:15:08
# 8  10         121 2010-07-19 19:05:40        Pierre 2014-07-28 18:15:02
# 9  11         136 2010-07-19 19:06:02      wahalulu 2014-07-23 21:28:18
#
#                                 WebsiteUrl                   Location  \
# 0           http://meta.stackexchange.com/         on the server farm
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
# first Id columns and second newname userId.

df_users.rename(columns={"Id": "userId"})
# Out:
#        userId  Reputation        CreationDate     DisplayName  \
# 0          -1           1 2010-07-19 06:55:26       Community
# 1           2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101 2010-07-19 19:03:27          Emmett
# 4           5        6792 2010-07-19 19:03:57           Shane
# ...       ...         ...                 ...             ...
# 40320   55743           1 2014-09-13 21:03:50       AussieMeg
# 40321   55744           6 2014-09-13 21:39:30       Mia Maria
# 40322   55745         101 2014-09-13 23:45:27    tronbabylove
# 40323   55746         106 2014-09-14 00:29:41             GPP
# 40324   55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
df_posts = pd.read_sql_query("select * from posts", engine)



posts.head()
# Out:
# Index(['Id', 'PostTypeId', 'AcceptedAnswerId', 'CreaionDate', 'Score',
#        'ViewCount', 'Body', 'OwnerUserId', 'LasActivityDate', 'Title', 'Tags',
#        'AnswerCount', 'CommentCount', 'FavoriteCount', 'LastEditorUserId',
#        'LastEditDate', 'CommunityOwnedDate', 'ParentId', 'ClosedDate',
#        'OwnerDisplayName', 'LastEditorDisplayName'],
#       dtype='object')

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns={"Id": "upostId","OwnerUserId": "userId" })
# Out:
#        upostId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0            1           1              15.0 2010-07-19 19:12:12     23
# 1            2           1              59.0 2010-07-19 19:12:57     22
# 2            3           1               5.0 2010-07-19 19:13:28     54
# 3            4           1             135.0 2010-07-19 19:13:31     13
# 4            5           2               NaN 2010-07-19 19:14:43     81
# ...        ...         ...               ...                 ...    ...
# 91971   115374           2               NaN 2014-09-13 23:45:39      2
# 91972   115375           1               NaN 2014-09-13 23:46:05      0
# 91973   115376           1               NaN 2014-09-14 01:27:54      1
# 91974   115377           2               NaN 2014-09-14 02:03:28      0
# 91975   115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body   userId  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
users_columns = pd.read_sql_query("select Id as userId, Reputation,Views,UpVotes,DownVotes from users", engine)
users_columns
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# ...       ...         ...    ...      ...        ...
# 40320   55743           1      0        0          0
# 40321   55744           6      1        0          0
# 40322   55745         101      0        0          0
# 40323   55746         106      1        0          0
# 40324   55747           1      0        0          0
#
# [40325 rows x 5 columns]

# %%
#Index(['Id', 'PostTypeId', 'AcceptedAnswerId', 'CreaionDate', 'Score',
#       'ViewCount', 'Body', 'OwnerUserId', 'LasActivityDate', 'Title', 'Tags',
#       'AnswerCount', 'CommentCount', 'FavoriteCount', 'LastEditorUserId',
#       'LastEditDate', 'CommunityOwnedDate', 'ParentId', 'ClosedDate',
#      'OwnerDisplayName', 'LastEditorDisplayName'],

#**posts columns**: postId, Score,userID,ViewCount,CommentCount
#{"Id": "upostId","OwnerUserId": "userId" })
posts_columns = pd.read_sql_query("select Id as postId, Score,OwnerUserId as userID,ViewCount,CommentCount from posts", engine)
posts_columns
# Out:
#        postId  Score   userID  ViewCount  CommentCount
# 0           1     23      8.0     1278.0             1
# 1           2     22     24.0     8198.0             1
# 2           3     54     18.0     3613.0             4
# 3           4     13     23.0     5224.0             2
# 4           5     81     23.0        NaN             3
# ...       ...    ...      ...        ...           ...
# 91971  115374      2    805.0        NaN             2
# 91972  115375      0  49365.0        9.0             0
# 91973  115376      1  55746.0        5.0             2
# 91974  115377      0    805.0        NaN             0
# 91975  115378      0   7250.0        NaN             0
#
# [91976 rows x 5 columns]

# %% [markdown]
# 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
pd.merge(sales, stores, on='stor_id').groupby('stor_id').agg({'qty': 'sum', 'ord_num': 'count'})
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/miniconda3/envs/test_env/lib/python3.7/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     690             try:
# --> 691                 data = self._rfile.read(num_bytes)
#     692                 break
#
# ~/miniconda3/envs/test_env/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~/miniconda3/envs/test_env/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
# ...

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.
